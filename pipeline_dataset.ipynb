# %% [markdown]
# This notebook allows to compute different feature from the dataset.
#
# IMPORTANT you have to launch the sementation file in order to compute the test seg with the left ventricule label. This new seg is then stored in Dataset/SegTest.
#
# In this notebook I use a feature extractor librairy I saw in a paper. Py-radiomics. It allows to compute feature easily without doing it by hand. This librairy can compute feature on the original scans if you give it the mask of the labels.
#
#
#
# I choose some of them. First the shape features, volume, sphreicity, ratio etc.
#
# Then there are the signal anlysis features taht uses pixel intensities values.
#
# Lastly I saw that texture could be interesting in our classification cases so I add some of them that were cited interesting.

# %%
import os
import numpy as np
import pandas as pd
import SimpleITK as sitk
from radiomics import featureextractor
import itertools
import re

# %%
# Py-radiomics extractor that extract radiomic features.
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.settings['normalize'] = True             # Z-score normalization
extractor.settings['normalizeScale'] = 100         # Stretch intensity to approx -300..+300
extractor.settings['removeOutliers'] = 3           # Clip extreme values beyond ±3σ
extractor.settings['voxelArrayShift'] = 300        # Shift to make intensities all positive

# === Discretization for texture ===
extractor.settings['binWidth'] = 5                 # Recommended for MRI after scaling

# === Resampling settings ===
extractor.settings['resampledPixelSpacing'] = [2, 2, 2]  # Isotropic 2mm resolution
extractor.settings['interpolator'] = 'sitkBSpline'       # Smooth interpolation for MRI

extractor.settings['additionalInfo'] = False
extractor.disableAllImageTypes()
extractor.enableImageTypeByName('Original')
extractor.disableAllFeatures()

# Feature que l'on veut : 
extractor.enableFeatureClassByName('shape') # Some shape features (volume, sphericity etc)
extractor.enableFeatureClassByName('firstorder') # Some signal features
extractor.enableFeatureClassByName("glcm")
extractor.enableFeatureClassByName("glrlm")

# %%
# I just did that to be have clean folder depending on feature selected.
output_string = ""
for cls, feats in extractor.enabledFeatures.items():
    output_string += f"{cls}_" 
output_string += "features"

# %%
print(output_string)
# Out:
# shape_features

# %%
BASE       = os.getcwd()
TRAIN_DIR  = os.path.join(BASE, "Dataset", "Train")
TEST_DIR   = os.path.join(BASE, "Dataset", "SegTest")
OUT_DIR    = os.path.join(BASE, "data",output_string)
os.makedirs(OUT_DIR, exist_ok=True)

# %%
def extract_per_patient(folder, sid):
    rec = {"Id": sid}
    for ph in ["ED", "ES"]:
        img = sitk.ReadImage(os.path.join(folder, f"{sid}_{ph}.nii"))
        msk = sitk.ReadImage(os.path.join(folder, f"{sid}_{ph}_seg.nii"))
        for lbl,name in [(1,"RV"),(3,"LV"),(2,"MY")]:
            try:
                feats = extractor.execute(img, msk, label=lbl)
                for k,v in feats.items():
                    rec[f"{ph}_{name}_{k.replace('original_','')}"] = v
            except ValueError:
                # si jamais pas de label
                # avec nos donnés en pratique on passe jamais dedans.
                for k in extractor.enabledFeatures['shape']:
                    rec[f"{ph}_{name}_{k}"] = np.nan
    return rec

def all_patient(src_dir):
    # First i forgot to sort that lead to indexes problem
    patient_folders = sorted(
        [s for s in os.listdir(src_dir) if os.path.isdir(os.path.join(src_dir, s))],
        key=lambda x: int(x)
    )

    # Extract features for each patient in the right order
    rows = [extract_per_patient(os.path.join(src_dir, s), s) for s in patient_folders]

    df = pd.DataFrame(rows)
    return df

def add_ratios(df,Train=True):
    
    # on récupère uniquement les features qui correspondent à des volume.
    # Dans les différents papiers la fractions d' ejection qui est un rapport revient souvent comme une feature importante. 
    # D'où l'idée de calculer différente ratio
    
    vol_cols = [c for c in df.columns if re.search(r'VoxelVolume$', c)]
    print(vol_cols)
    
    # on utilise combinations et pas product de itertools pour ne pas calculer A/B et B/A.
    # Car ce n'est pas très utile d'avoir des features redondantes comme ça
    ratio_frames = {}         

    for a,b in itertools.product(vol_cols, repeat = 2):
        if a != b :
            name = f"{a}_over_{b}"              
            ratio = np.divide(df[a], df[b])
            ratio_frames[name] = ratio

    # merge 
    df = pd.concat([df, pd.DataFrame(ratio_frames)], axis=1)

    return df
 

def compute_body_surface_area(height,weight): 
    "Return the body surface area from height and weight. (Formula of Du Bois)"
    
    return 0.007184 * (height**0.725 )* (weight**0.425)

def add_body_surface_area_feature(df : pd.DataFrame ,name_column_height = "Height",name_column_weight = "Weight"):
    # Add for each row the BSA associated.
    
    if (name_column_height and name_column_weight in df.columns) and ("body_surface" not in df.columns)  :
        df["body_surface"] = compute_body_surface_area(df[name_column_height],df[name_column_weight])
        #print("Body surface area feature added")
    else : 
        print("provide a dataframe with a height and weight feature")
       

def add_meta_data(df,Train= True):  
    if Train : 
        metaData = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTrain.csv"))
        metaData.drop(columns=["Category"],inplace=True)
        # print(metaData.head())
    else :
        metaData = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTest.csv"))
        # print(metaData.head())
    
    # I had some issues with int index as 001 can be translated to 1..
    # So I needed to ensure all Id have the same size by filling from the left 0s .
    df["Id"] = df["Id"].astype(str).str.zfill(3)  
    metaData["Id"] = metaData["Id"].astype(str).str.zfill(3)
    df = df.merge(metaData, on="Id", how="left")
    
    add_body_surface_area_feature(df)           
    df.drop(columns=["Height", "Weight"], errors="ignore", inplace=True)
    
    return df

# %%
df_train_all_features = all_patient(TRAIN_DIR)
df_test_all_features = all_patient(TEST_DIR)
# Out:
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191a00b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191a00b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914b220): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914b220): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119594d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119594d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf26d90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf26d90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cfa2d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cfa2d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf26d90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf26d90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf79ff0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf79ff0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191a00b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191a00b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191f9e10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191f9e10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cfa2d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cfa2d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf7d850): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cfa2d40): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11
ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/094/094_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914bb60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/094/094_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914bb60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/094/094_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11910dbb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11910dbb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191ae2c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1191ae2c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11919cae0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11919cae0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/095/095_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc759f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc759f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11917ccf0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11917ccf0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d91c930): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d91c930): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/096/096_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119542cb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119542cb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119558ba0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119558ba0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d910d20): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d910d20): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/097/097_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf48f50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf48f50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf2bc30): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cf2bc30): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc07fe0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc07fe0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/098/098_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11ccafcb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11ccafcb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc759f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc759f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914bb60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11914bb60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/099/099_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x119151140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d90a430): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11d90a430): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc93f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc75b80): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11cc75b80): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/100/100_ES_seg.nii has unexpected scales in sform

# %%
df_train = add_ratios(df_train_all_features,Train=True)
df_test = add_ratios(df_test_all_features,Train=False)
# Out:
# ['ED_RV_shape_VoxelVolume', 'ED_LV_shape_VoxelVolume', 'ED_MY_shape_VoxelVolume', 'ES_RV_shape_VoxelVolume', 'ES_LV_shape_VoxelVolume', 'ES_MY_shape_VoxelVolume']
# ['ED_RV_shape_VoxelVolume', 'ED_LV_shape_VoxelVolume', 'ED_MY_shape_VoxelVolume', 'ES_RV_shape_VoxelVolume', 'ES_LV_shape_VoxelVolume', 'ES_MY_shape_VoxelVolume']

# %%
df_train = add_meta_data(df_train,Train=True)
df_test = add_meta_data(df_test,Train=False)

# %%
# Création du label set
y = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTrain.csv"), usecols=["Id", "Category"])
y["Id"] = y["Id"].astype(str).str.zfill(3)  # Pour correspondre à df_train

# Alignement de y 
y_aligned = y.set_index("Id").loc[df_train["Id"]].reset_index()

df_train.to_csv(os.path.join(OUT_DIR,"TrainningDataset.csv"), index=False)
df_test.to_csv(os.path.join(OUT_DIR,"TestingDataset.csv"), index=False)
y_aligned.to_csv(os.path.join(OUT_DIR,"TrainningDatasetCategory.csv"), index=False)
