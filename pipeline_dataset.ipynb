# %% [markdown]
# This notebook allows to compute different feature from the dataset.
#
# IMPORTANT you have to launch the sementation file in order to compute the test seg with the left ventricule label. This new seg is then stored in Dataset/SegTest.
#
# In this notebook I use a feature extractor librairy I saw in a paper. Py-radiomics. It allows to compute feature easily without doing it by hand. This librairy can compute feature on the original scans if you give it the mask of the labels.
#
#
#
# I choose some of them. First the shape features, volume, sphreicity, ratio etc.
#
# Then there are the signal anlysis features taht uses pixel intensities values.
#
# Lastly I saw that texture could be interesting in our classification cases so I add some of them that were cited interesting.

# %%
import os
import numpy as np
import pandas as pd
import SimpleITK as sitk
from radiomics import featureextractor
import itertools
import re

# %%
# Py-radiomics extractor that extract radiomic features.
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.settings['additionalInfo'] = False
extractor.disableAllImageTypes()
extractor.enableImageTypeByName('Original')
extractor.disableAllFeatures()

# Feature que l'on veut : 
extractor.enableFeatureClassByName('shape') # Some shape features (volume, sphericity etc)
extractor.enableFeatureClassByName('firstorder') # Some signal features
extractor.enableFeatureClassByName("glcm")

# %%
# I just did that to be have clean folder depending on feature selected.
output_string = ""
for cls, feats in extractor.enabledFeatures.items():
    output_string += f"{cls}_" 
output_string += "features"

# %%
print(output_string)
# Out:
# shape_firstorder_glcm_features

# %%
BASE       = os.getcwd()
TRAIN_DIR  = os.path.join(BASE, "Dataset", "Train")
TEST_DIR   = os.path.join(BASE, "Dataset", "SegTest")
OUT_DIR    = os.path.join(BASE, "data",output_string)
os.makedirs(OUT_DIR, exist_ok=True)

# %%
def extract_per_patient(folder, sid):
    rec = {"Id": sid}
    for ph in ["ED", "ES"]:
        img = sitk.ReadImage(os.path.join(folder, f"{sid}_{ph}.nii"))
        msk = sitk.ReadImage(os.path.join(folder, f"{sid}_{ph}_seg.nii"))
        for lbl,name in [(1,"RV"),(3,"LV"),(2,"MY")]:
            try:
                feats = extractor.execute(img, msk, label=lbl)
                for k,v in feats.items():
                    rec[f"{ph}_{name}_{k.replace('original_','')}"] = v
            except ValueError:
                # si jamais pas de label
                # avec nos donnés en pratique on passe jamais dedans.
                for k in extractor.enabledFeatures['shape']:
                    rec[f"{ph}_{name}_{k}"] = np.nan
    return rec

# %%
def all_patient(src_dir):
    """
    Extract features for all patients in the given directory.
    Ensures deterministic order by sorting folder names numerically.
    """
    # Sort patient folders numerically (e.g., ['1', '2', ..., '10', '11'])
    patient_folders = sorted(
        [s for s in os.listdir(src_dir) if os.path.isdir(os.path.join(src_dir, s))],
        key=lambda x: int(x)
    )

    # Extract features for each patient in order
    rows = [extract_per_patient(os.path.join(src_dir, s), s) for s in patient_folders]

    df = pd.DataFrame(rows)
    return df

# %%
def add_ratios(df,Train=True):
    
    # on récupère uniquement les features qui correspondent à des volume.
    # Dans les différents papiers la fractions d' ejection qui est un rapport revient souvent comme une feature importante. 
    # D'où l'idée de calculer différente ratio
    
    vol_cols = [c for c in df.columns if re.search(r'MeshVolume$', c)]
    print(vol_cols)
    
    # on utilise combinations et pas product de itertools pour ne pas calculer A/B et B/A.
    # Car ce n'est pas très utile d'avoir des features redondantes comme ça
    ratio_frames = {}         

    for a,b in itertools.combinations(vol_cols, 2):
        name = f"{a}_over_{b}"              
        ratio = np.divide(df[a], df[b])
        ratio_frames[name] = ratio

    # merge 
    df = pd.concat([df, pd.DataFrame(ratio_frames)], axis=1)

    return df

# %%
def compute_body_surface_area(height,weight): 
    "Return the body surface area from height and weight. (Formula of Du Bois)"
    
    return 0.007184 * (height**0.725 )* (weight**0.425)

def add_body_surface_area_feature(df : pd.DataFrame ,name_column_height = "Height",name_column_weight = "Weight"):
    # Add for each row the BSA associated.
    
    if (name_column_height and name_column_weight in df.columns) and ("body_surface" not in df.columns)  :
        df["body_surface"] = compute_body_surface_area(df[name_column_height],df[name_column_weight])
        #print("Body surface area feature added")
    else : 
        print("provide a dataframe with a height and weight feature")

# %%
def add_meta_data(df,Train= True):  
    if Train : 
        metaData = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTrain.csv"))
        metaData.drop(columns=["Category"],inplace=True)
        # print(metaData.head())
    else :
        metaData = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTest.csv"))
        # print(metaData.head())
    
    # I had some issues with int index as 001 can be translated to 1..
    # So I needed to ensure all Id have the same size by filling from the left 0s .
    df["Id"] = df["Id"].astype(str).str.zfill(3)  
    metaData["Id"] = metaData["Id"].astype(str).str.zfill(3)
    df = df.merge(metaData, on="Id", how="left")
    
    add_body_surface_area_feature(df)           
    df.drop(columns=["Height", "Weight"], errors="ignore", inplace=True)
    
    return df

# %%
df_train_all_features = all_patient(TRAIN_DIR)
df_test_all_features = all_patient(TEST_DIR)
# Out:
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110094440): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110094440): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100979f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100979f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fecd0b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fecd0b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/001/001_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110093d00): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110093d00): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110093d00): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110093d00): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100982f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100982f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099f80): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099f80): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/002/002_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fecf810): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fecf810): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed1500): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed1500): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10df31120): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10df31120): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1132bc1e0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1132bc1e0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/003/003_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed0530): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed0530): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099930): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099930): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009adb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009adb0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11314d620): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11314d620): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/004/004_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a4c60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a4c60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1131706d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1131706d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a2830): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a2830): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113104cc0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113104cc0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/005/005_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11313fd10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11313fd10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1330527d0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1135ffe50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1135ffe50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/006/006_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1135ffe50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1135ffe50): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009b630): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009b630): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed62b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed62b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3ba7b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3ba7b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/007/007_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed0f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed0f90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed7b10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed7b10): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3b58b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3b58b0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113145740): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113145740): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/008/008_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113144610): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113144610): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed1040): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed1040): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a9440): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a9440): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a8770): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a8770): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/009/009_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a5410): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100a5410): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3be300): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3be300): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3bc070): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3bc070): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009d780): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x11009d780): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/010/010_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113145fd0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113145fd0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10feda790): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10feda790): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3bb6e0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3bb6e0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c1f220): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c1f220): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/011/011_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113144610): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x113144610): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c0fde0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c0fde0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100acfc0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100acfc0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c2140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c2140): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/012/012_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed4600): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fed4600): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3b8910): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3b8910): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10feea7c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10feea7c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fee3e90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fee3e90): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/013/013_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c30c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c30c0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedac60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedac60): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedbad0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedbad0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c25160): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c25160): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/014/014_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100aa740): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100aa740): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedd710): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedd710): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fee6790): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fee6790): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c0fde0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x111c0fde0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/015/015_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1131470f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1131470f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ED.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100ae0f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x1100ae0f0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ED_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c6780): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10f3c6780): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ES.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099bd0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x110099bd0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/016/016_ES_seg.nii has unexpected scales in sform
#
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# WARNING: In /Users/ec2-user/actions-runner/_work/SimpleITK/SimpleITK/bld/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 2008
# NiftiImageIO (0x10fedc6e0): /Users/rplanchon/Documents/telecom/IMA/S2/IMA205/Challenge/CardiacPathoPrediction/Dataset/Train/017/017_ED.nii has unexpected scales in sform
#
# ...
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
df_train = add_ratios(df_train_all_features,Train=True)
df_test = add_ratios(df_test_all_features,Train=False)
# Out:
# ['ED_RV_shape_MeshVolume', 'ED_LV_shape_MeshVolume', 'ED_MY_shape_MeshVolume', 'ES_RV_shape_MeshVolume', 'ES_LV_shape_MeshVolume', 'ES_MY_shape_MeshVolume']
# ['ED_RV_shape_MeshVolume', 'ED_LV_shape_MeshVolume', 'ED_MY_shape_MeshVolume', 'ES_RV_shape_MeshVolume', 'ES_LV_shape_MeshVolume', 'ES_MY_shape_MeshVolume']

# %%
df_train = add_meta_data(df_train,Train=True)
df_test = add_meta_data(df_test,Train=False)

# %%
# df_train.to_csv(os.path.join(OUT_DIR,"TrainningDataset.csv"), index=False)
# df_test.to_csv(os.path.join(OUT_DIR,"TestingDataset.csv"), index=False)

# %%
# # Label dataset 

# y = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTrain.csv"), usecols=["Id", "Category"])
# y.to_csv(os.path.join(OUT_DIR,"TrainningDatasetCategory.csv"), index=False)

# %%
# Création du label set
y = pd.read_csv(os.path.join(BASE,"Dataset","metaDataTrain.csv"), usecols=["Id", "Category"])
y["Id"] = y["Id"].astype(str).str.zfill(3)  # Pour correspondre à df_train


# Alignement correct de y
y_aligned = y.set_index("Id").loc[df_train["Id"]].reset_index()

# Sauvegarde propre
df_train.to_csv(os.path.join(OUT_DIR,"TrainningDataset.csv"), index=False)
df_test.to_csv(os.path.join(OUT_DIR,"TestingDataset.csv"), index=False)
y_aligned.to_csv(os.path.join(OUT_DIR,"TrainningDatasetCategory.csv"), index=False)
# Out:
# IDs in X but not in y: set()
# IDs in y but not in X: set()
# Correspondance parfaite entre X et y.
